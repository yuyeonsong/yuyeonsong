# %% [markdown]
# <a href="https://colab.research.google.com/github/yuyeonsong/yuyeonsong/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("3개의 정수값을 입력하시오")
n1 = int(input("n1의 정수값을 입력"))
n2 = int(input("n2의 정수값을 입력"))
n3 = int(input("n3의 정수값을 입력"))

total = n1 + n2 + n3
average = total / 3
print(average)
# Out:
# 3개의 정수값을 입력하시오
# n1의 정수값을 입력20
# n2의 정수값을 입력30
# n3의 정수값을 입력50
# 33.333333333333336
